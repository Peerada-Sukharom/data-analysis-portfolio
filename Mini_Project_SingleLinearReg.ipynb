# %% [markdown]
# <a href="https://colab.research.google.com/github/Peerada-Sukharom/data-analysis-portfolio/blob/main/Mini_Project_SingleLinearReg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Mini Project: GPA Prediction

# %% [markdown]
# ### **Objective**
# The objectives is to build a simple linear regression model to predict students’ GPA based on their SAT scores and explore the relationship between these two academic indicators.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = "/content/drive/My Drive/semester2_2566/SATscores.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
# Mounted at /content/drive
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
# Out:
# (84, 2)

# %%
df.isnull().sum()
# Out:
# SAT    0
# GPA    0
# dtype: int64

# %% [markdown]
# ###Exploratory Data Analysis (EDA)

# %%
#check the correlation between features in the dataset
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
# X array of features for training
X = df[['SAT']]
X.head(3)
# Out:
#     SAT
# 0  1714
# 1  1664
# 2  1760

# %%
# y array with the target variable
y = df[['GPA']]
y.head(3)
# Out:
#     GPA
# 0  2.40
# 1  2.52
# 2  2.54

# %% [markdown]
# ###Train Test Split

# %%
#Import package of select model for split Training and Testing dataset
from sklearn.model_selection import train_test_split

# %%
# Using function "train_test_split()"
# Seperate dataset into 4 set: X_train, X_test, y_train and y_test
# test_size = 0.3 is mean seperate dataset into 70% for training and 30% for testing
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %%
X_train.head(3)
# Out:
#      SAT
# 1   1664
# 18  1842
# 75  2015

# %%
X_test.head(3)
# Out:
#      SAT
# 12  1735
# 36  1808
# 6   1764

# %%
y_train.head(3)
# Out:
#      GPA
# 1   2.52
# 18  3.17
# 75  3.62

# %%
y_test.head(3)
# Out:
#      GPA
# 12  3.08
# 36  3.32
# 6   3.00

# %% [markdown]
# ###Creating and Training the Model

# %%
##using package LinearRegression
from sklearn.linear_model import LinearRegression

# %%
# Create an instance of a linear regression model
model = LinearRegression()

# %%
#fit it to the data with the fit() function:
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Get results
#Once you have your model fitted, you can get the results to verify that the model performs as expected and to interpret it.
#You can obtain the coefficient of determination, 𝑅², with .score() called on model:
# 𝑅²
print('Coefficient of determination: 𝑅² or Accuracy of Model Training :',model.score(X_train, y_train))
print('Coefficient of determination: 𝑅² or Accuracy of Model Testing :',model.score(X_test, y_test))
# Print the Intercept:
print('Intercept:', model.intercept_)
# Out:
# Coefficient of determination: 𝑅² or Accuracy of Model Training : 0.46900010913003176
# Coefficient of determination: 𝑅² or Accuracy of Model Testing : 0.21700424536130725
# Intercept: [0.17944498]

# %% [markdown]
# ###Exploring results

# %%
#Predictin "Yearly Amount Spent" via using model
y_prediction = model.predict(X_test)
y_prediction
# Out:
# array([[3.13845939],
#        [3.26295971],
#        [3.18791842],
#        [3.20667874],
#        [3.66033744],
#        [3.38575454],
#        [2.96620553],
#        [3.06682907],
#        [3.48126164],
#        [3.08217842],
#        [3.29365842],
#        [3.25272681],
#        [3.18280197],
#        [3.34652842],
#        [3.20667874],
#        [3.36017229],
#        [3.33459003],
#        [3.23908294],
#        [3.13845939],
#        [3.30218584],
#        [3.39769293],
#        [3.21179519],
#        [3.26637068],
#        [3.18791842],
#        [3.10264423],
#        [3.05659617]])

# %%
#Matplotlib: Scatter plot
plt.scatter(y_test,y_prediction, color='r', alpha=0.5)
plt.title("Linear Regression Model Prediction: GPA ")
plt.xlabel('GPX Test (True Values)')
plt.ylabel('GPX Predicted values')
plt.show()

# %%
#seaborn.regplot
#Plot data and a linear regression model fit.
sns.regplot(x = y_test,y = y_prediction, color='g',scatter_kws={'alpha':0.5})
plt.title("Linear Regression Model Prediction: GPA ")
plt.xlabel('GPX (True Values)')
plt.ylabel('Predicted GPA values')
plt.show()

# %% [markdown]
# ###**Result**
# The model showed a strong positive correlation between SAT scores and GPA, indicating that higher SAT scores tend to be associated with higher GPAs.
